# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# SCRIPT: 2.5_view_calendario_publico
# LOCAL: 3_gold/src/2_calendario_eventos/
# OBJETIVO: View pública com calendário de eventos futuros já agendados e obtidos pela tabela do script 2_silver/src/2_calendario_eventos/2.5_eventos_futuros_transform
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

from pyspark.sql.functions import col

# Carregar dados da Bronze e aplicar transformações
df_view = spark.table("silver_eventos_futuros").orderBy("data_hora")

df_view.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("gold_view_calendario_futuro")

display(df_view)
