# %%
df_bronze = spark.table("bronze_frentes")

df_silver = df_bronze.select(
"id"
,"idLegislatura"	
,"titulo"
).distinct()

df_silver.write.mode("overwrite").saveAsTable("silver_frentes")

# %%
display(spark.table("silver_frentes"))
