# %%
 

df_referencia_tipoevento = spark.table("bronze_referencia_tipoevento")

df_silver = df_bronze.select(
 "cod"
,"nome"
).distinct()
 
df_silver = df_silver.withColumn("cod", df_silver["cod"].cast("int"))

df_silver.write \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("silver_referencia_tipoevento")

display(spark.table("silver_referencia_tipoevento"))
